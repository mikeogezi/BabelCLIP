# %%
import json
from PIL import Image
import numpy as np
import ipyplot
from random import sample, seed

_in = json.load(open('ranked/ranked_sample_synsets_l14.json', 'r'))

# %%
seed(10)
np.random.seed(10)
samples = sample(_in.items(), 50)[25:]

force_b64 = False
start_cnt = 25

for i, (id, v) in enumerate(samples):
    print('{}) {} -> {}\n\t{}'.format(i+1+start_cnt, id, v['gloss'], ', '.join(v['lemmas'])))
    g = v['goldImages']
    m = sorted_images = [j['path'] for j in sorted(v['images'], key=lambda x: x['ex+lemmas_confidence'] or -1, reverse=True)]    
    num_images = min([len(g), len(m), 5])
    if num_images > 1 and not np.array_equiv(g, m):
        r = np.random.rand()
        if r > 0.5:
            first, second = [(g, 'Gold'), (m, 'System')]
        else:
            second, first = [(g, 'Gold'), (m, 'System')]

        for i, img_tup in enumerate([first, second]):
            if i >= 1:
                print('-'*100)
            print(img_tup[1])
            ipyplot.plot_images(img_tup[0], max_images=num_images, img_width=150, show_url=False, labels=range(1, num_images+1), force_b64=force_b64)
    else:
        print('This synset-image mapping was filtered out because both predictions were equivalent')
    
#     print('\nGold')
#     print('----')
#     ipyplot.plot_images(v['goldImages'], max_images=num_images, img_width=128)

#     print('CLIP (lemmas-based)')
#     print('--------------------')
#     sorted_images = [j['path'] for j in sorted(v['images'], key=lambda x: x['lemmas_confidence'], reverse=True)]
#     ipyplot.plot_images(sorted_images, max_images=num_images, img_width=128)
    
#     print('CLIP (gloss-based)')
#     print('-------------------')
#     sorted_images = [j['path'] for j in sorted(v['images'], key=lambda x: x['gloss_confidence'], reverse=True)]
#     ipyplot.plot_images(sorted_images, max_images=num_images, img_width=128)
    
#     print('\nCLIP (example-based)')
#     print('---------------------')
#     sorted_images = [j['path'] for j in sorted(v['images'], key=lambda x: x['example_confidence'] or -1, reverse=True)]
#     ipyplot.plot_images(sorted_images, max_images=num_images, img_width=150)
    
#     print('\nCLIP (ex+gloss-based)')
#     print('---------------------')
#     sorted_images = [j['path'] for j in sorted(v['images'], key=lambda x: x['ex+gloss_confidence'] or -1, reverse=True)]
#     ipyplot.plot_images(sorted_images, max_images=num_images, img_width=150)
    
#     print('\nCLIP (ex+lemmas-based)')
#     print('---------------------')
#     sorted_images = [j['path'] for j in sorted(v['images'], key=lambda x: x['ex+lemmas_confidence'] or -1, reverse=True)]
#     ipyplot.plot_images(sorted_images, max_images=num_images, img_width=150)
# Out:
# 26) bn:00023004n -> Keeping account of the costs of items in production
# 	cost_accounting, cost_accounts, standard_accounting, cost_management, budget_management, cost_accountant, costing, cost_control
# This synset-image mapping was filtered out because both predictions were equivalent
# 27) bn:00044708n -> Failure to attend (especially school)
# 	truancy, hooky, skipping_class, skipping_school, pipping_off, playing_hooky, truant_officer, pipping, truency, pipped_off, truancy_officer, verification_officer, hookie, playing_truant, truanting, pip_off, truants, cutting_school, pips_off, hookey, playing_hookie
# Gold
# /tmp/ipykernel_4030364/755805782.py:3: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   samples = sample(_in.items(), 50)[25:]
#     <style>
#         #ipyplot-html-viewer-toggle-jWAAoZdf7axDje2C6uUiBT {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-jWAAoZdf7axDje2C6uUiBT {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-jWAAoZdf7axDje2C6uUiBT {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-jWAAoZdf7axDje2C6uUiBT:checked ~ #ipyplot-html-viewer-textarea-jWAAoZdf7axDje2C6uUiBT {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-jWAAoZdf7axDje2C6uUiBT:checked + #ipyplot-html-viewer-label-jWAAoZdf7axDje2C6uUiBT:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-jWAAoZdf7axDje2C6uUiBT">
#         <label id="ipyplot-html-viewer-label-jWAAoZdf7axDje2C6uUiBT" for="ipyplot-html-viewer-toggle-jWAAoZdf7axDje2C6uUiBT">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-jWAAoZdf7axDje2C6uUiBT" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-LaSFR2cSpKGxpNwGazV8BX {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-LaSFR2cSpKGxpNwGazV8BX {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-LaSFR2cSpKGxpNwGazV8BX">
#     <div class="ipyplot-placeholder-div-LaSFR2cSpKGxpNwGazV8BX">
#         <div id="ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX-GBe5V67hYzPHmyLDSMZF8S" class="ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="babelpic-gold/images/bn:00044708n_1_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX-GBe5V67hYzPHmyLDSMZF8S">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LaSFR2cSpKGxpNwGazV8BX">
#         <div id="ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX-4HyqjjTd5rYfYn4gKgq3yT" class="ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="babelpic-gold/images/bn:00044708n_5_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX-4HyqjjTd5rYfYn4gKgq3yT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-LaSFR2cSpKGxpNwGazV8BX {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-LaSFR2cSpKGxpNwGazV8BX {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-LaSFR2cSpKGxpNwGazV8BX">
#     <div class="ipyplot-placeholder-div-LaSFR2cSpKGxpNwGazV8BX">
#         <div id="ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX-GBe5V67hYzPHmyLDSMZF8S" class="ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="babelpic-gold/images/bn:00044708n_1_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX-GBe5V67hYzPHmyLDSMZF8S">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-LaSFR2cSpKGxpNwGazV8BX">
#         <div id="ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX-4HyqjjTd5rYfYn4gKgq3yT" class="ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="babelpic-gold/images/bn:00044708n_5_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-LaSFR2cSpKGxpNwGazV8BX-4HyqjjTd5rYfYn4gKgq3yT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# ----------------------------------------------------------------------------------------------------
# System
#     <style>
#         #ipyplot-html-viewer-toggle-fUeRxvBmAkEXPKHnLSJq6L {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-fUeRxvBmAkEXPKHnLSJq6L {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-fUeRxvBmAkEXPKHnLSJq6L {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-fUeRxvBmAkEXPKHnLSJq6L:checked ~ #ipyplot-html-viewer-textarea-fUeRxvBmAkEXPKHnLSJq6L {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-fUeRxvBmAkEXPKHnLSJq6L:checked + #ipyplot-html-viewer-label-fUeRxvBmAkEXPKHnLSJq6L:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-fUeRxvBmAkEXPKHnLSJq6L">
#         <label id="ipyplot-html-viewer-label-fUeRxvBmAkEXPKHnLSJq6L" for="ipyplot-html-viewer-toggle-fUeRxvBmAkEXPKHnLSJq6L">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-fUeRxvBmAkEXPKHnLSJq6L" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-ksoLxah2wyQcMtapB8hHyg {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ksoLxah2wyQcMtapB8hHyg {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ksoLxah2wyQcMtapB8hHyg">
#     <div class="ipyplot-placeholder-div-ksoLxah2wyQcMtapB8hHyg">
#         <div id="ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg-eYM9eTkvd9cpUNeVrDucpW" class="ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="pulled_images/bn:00044708n/3.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg-eYM9eTkvd9cpUNeVrDucpW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ksoLxah2wyQcMtapB8hHyg">
#         <div id="ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg-FmedQHXVyvJcspWhwYnsUm" class="ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="pulled_images/bn:00044708n/1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg-FmedQHXVyvJcspWhwYnsUm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-ksoLxah2wyQcMtapB8hHyg {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-ksoLxah2wyQcMtapB8hHyg {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-ksoLxah2wyQcMtapB8hHyg">
#     <div class="ipyplot-placeholder-div-ksoLxah2wyQcMtapB8hHyg">
#         <div id="ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg-eYM9eTkvd9cpUNeVrDucpW" class="ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="pulled_images/bn:00044708n/3.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg-eYM9eTkvd9cpUNeVrDucpW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-ksoLxah2wyQcMtapB8hHyg">
#         <div id="ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg-FmedQHXVyvJcspWhwYnsUm" class="ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="pulled_images/bn:00044708n/1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-ksoLxah2wyQcMtapB8hHyg-FmedQHXVyvJcspWhwYnsUm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 28) bn:00034592n -> The procedure of taking inked impressions of a person's fingerprints for the purpose of identification
# 	fingerprinting
# System
#     <style>
#         #ipyplot-html-viewer-toggle-Zp29zTamzJwAhkC8KRLvNK {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-Zp29zTamzJwAhkC8KRLvNK {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-Zp29zTamzJwAhkC8KRLvNK {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-Zp29zTamzJwAhkC8KRLvNK:checked ~ #ipyplot-html-viewer-textarea-Zp29zTamzJwAhkC8KRLvNK {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-Zp29zTamzJwAhkC8KRLvNK:checked + #ipyplot-html-viewer-label-Zp29zTamzJwAhkC8KRLvNK:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-Zp29zTamzJwAhkC8KRLvNK">
#         <label id="ipyplot-html-viewer-label-Zp29zTamzJwAhkC8KRLvNK" for="ipyplot-html-viewer-toggle-Zp29zTamzJwAhkC8KRLvNK">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-Zp29zTamzJwAhkC8KRLvNK" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-5Bv2AgF9q7yTMDARYD6yRi {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-5Bv2AgF9q7yTMDARYD6yRi">
#     <div class="ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi">
#         <div id="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-ej9xLagnFFVNhoEvYMieHn" class="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="pulled_images/bn:00034592n/11.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-ej9xLagnFFVNhoEvYMieHn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi">
#         <div id="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-BAonAc48JS8oDv6x9iJwvT" class="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="pulled_images/bn:00034592n/5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-BAonAc48JS8oDv6x9iJwvT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi">
#         <div id="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-CEzmcuos6oUtLDxhX2WZgm" class="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="pulled_images/bn:00034592n/6.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-CEzmcuos6oUtLDxhX2WZgm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi">
#         <div id="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-kaJ3fZ7cWYgECadzVCCfM3" class="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="pulled_images/bn:00034592n/15.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-kaJ3fZ7cWYgECadzVCCfM3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi">
#         <div id="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-9Zg8XcqRoRpKYPN9NjfNbY" class="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="pulled_images/bn:00034592n/7.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-9Zg8XcqRoRpKYPN9NjfNbY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-5Bv2AgF9q7yTMDARYD6yRi {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-5Bv2AgF9q7yTMDARYD6yRi">
#     <div class="ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi">
#         <div id="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-ej9xLagnFFVNhoEvYMieHn" class="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="pulled_images/bn:00034592n/11.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-ej9xLagnFFVNhoEvYMieHn">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi">
#         <div id="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-BAonAc48JS8oDv6x9iJwvT" class="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="pulled_images/bn:00034592n/5.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-BAonAc48JS8oDv6x9iJwvT">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi">
#         <div id="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-CEzmcuos6oUtLDxhX2WZgm" class="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="pulled_images/bn:00034592n/6.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-CEzmcuos6oUtLDxhX2WZgm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi">
#         <div id="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-kaJ3fZ7cWYgECadzVCCfM3" class="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="pulled_images/bn:00034592n/15.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-kaJ3fZ7cWYgECadzVCCfM3">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-5Bv2AgF9q7yTMDARYD6yRi">
#         <div id="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-9Zg8XcqRoRpKYPN9NjfNbY" class="ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="pulled_images/bn:00034592n/7.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-5Bv2AgF9q7yTMDARYD6yRi-9Zg8XcqRoRpKYPN9NjfNbY">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# ----------------------------------------------------------------------------------------------------
# Gold
#     <style>
#         #ipyplot-html-viewer-toggle-kq3Hb296WMSvuhP8YDNynw {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-kq3Hb296WMSvuhP8YDNynw {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-kq3Hb296WMSvuhP8YDNynw {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-kq3Hb296WMSvuhP8YDNynw:checked ~ #ipyplot-html-viewer-textarea-kq3Hb296WMSvuhP8YDNynw {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-kq3Hb296WMSvuhP8YDNynw:checked + #ipyplot-html-viewer-label-kq3Hb296WMSvuhP8YDNynw:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-kq3Hb296WMSvuhP8YDNynw">
#         <label id="ipyplot-html-viewer-label-kq3Hb296WMSvuhP8YDNynw" for="ipyplot-html-viewer-toggle-kq3Hb296WMSvuhP8YDNynw">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-kq3Hb296WMSvuhP8YDNynw" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-JyFLCMbEwA4VVVcfmZMYoW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-JyFLCMbEwA4VVVcfmZMYoW">
#     <div class="ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW">
#         <div id="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-UKBHwoXgKUHU24VPTPSURm" class="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="babelpic-gold/images/bn:00034592n_0_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-UKBHwoXgKUHU24VPTPSURm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW">
#         <div id="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-AwprKM7i3XTB7jTU5Nn4tx" class="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="babelpic-gold/images/bn:00034592n_11_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-AwprKM7i3XTB7jTU5Nn4tx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW">
#         <div id="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-n9N7pSwSBThZ6m5yxaYWbE" class="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="babelpic-gold/images/bn:00034592n_12_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-n9N7pSwSBThZ6m5yxaYWbE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW">
#         <div id="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-D3sLiPtKHSnunwoaPy4FBv" class="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="babelpic-gold/images/bn:00034592n_13_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-D3sLiPtKHSnunwoaPy4FBv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW">
#         <div id="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-Ub98q8S3tjPMiXTNdKPfr9" class="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="babelpic-gold/images/bn:00034592n_14_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-Ub98q8S3tjPMiXTNdKPfr9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-JyFLCMbEwA4VVVcfmZMYoW {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-JyFLCMbEwA4VVVcfmZMYoW">
#     <div class="ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW">
#         <div id="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-UKBHwoXgKUHU24VPTPSURm" class="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="babelpic-gold/images/bn:00034592n_0_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-UKBHwoXgKUHU24VPTPSURm">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW">
#         <div id="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-AwprKM7i3XTB7jTU5Nn4tx" class="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="babelpic-gold/images/bn:00034592n_11_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-AwprKM7i3XTB7jTU5Nn4tx">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW">
#         <div id="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-n9N7pSwSBThZ6m5yxaYWbE" class="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="babelpic-gold/images/bn:00034592n_12_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-n9N7pSwSBThZ6m5yxaYWbE">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW">
#         <div id="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-D3sLiPtKHSnunwoaPy4FBv" class="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="babelpic-gold/images/bn:00034592n_13_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-D3sLiPtKHSnunwoaPy4FBv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-JyFLCMbEwA4VVVcfmZMYoW">
#         <div id="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-Ub98q8S3tjPMiXTNdKPfr9" class="ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="babelpic-gold/images/bn:00034592n_14_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-JyFLCMbEwA4VVVcfmZMYoW-Ub98q8S3tjPMiXTNdKPfr9">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# 29) bn:00009621n -> A card game for two players in which the object is to win all of the other player's cards
# 	beggar-my-neighbor, beggar-my-neighbour, strip-jack-naked, beat_jack_out_of_doors, beat_your_neighbour_out_of_doors, beat_your_neighbor_out_of_doors, beggar-your-neighbor, beggar_my_neighbor, strip_jack_naked, beggar_my_neighbour
# This synset-image mapping was filtered out because both predictions were equivalent
# 30) bn:00085711v -> Be engaged in a fight; carry on a fight
# 	fight, contend, struggle
# Gold
#     <style>
#         #ipyplot-html-viewer-toggle-TWSx2d8cxsCptiDYqRUSJ5 {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-TWSx2d8cxsCptiDYqRUSJ5 {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-TWSx2d8cxsCptiDYqRUSJ5 {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-TWSx2d8cxsCptiDYqRUSJ5:checked ~ #ipyplot-html-viewer-textarea-TWSx2d8cxsCptiDYqRUSJ5 {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-TWSx2d8cxsCptiDYqRUSJ5:checked + #ipyplot-html-viewer-label-TWSx2d8cxsCptiDYqRUSJ5:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-TWSx2d8cxsCptiDYqRUSJ5">
#         <label id="ipyplot-html-viewer-label-TWSx2d8cxsCptiDYqRUSJ5" for="ipyplot-html-viewer-toggle-TWSx2d8cxsCptiDYqRUSJ5">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-TWSx2d8cxsCptiDYqRUSJ5" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-9LJ8UBNqHHvJzjddou7PLp {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-9LJ8UBNqHHvJzjddou7PLp {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-9LJ8UBNqHHvJzjddou7PLp">
#     <div class="ipyplot-placeholder-div-9LJ8UBNqHHvJzjddou7PLp">
#         <div id="ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp-mtfMEKgqfGzmskxTmWygHc" class="ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="babelpic-gold/images/bn:00085711v_0_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp-mtfMEKgqfGzmskxTmWygHc">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-9LJ8UBNqHHvJzjddou7PLp">
#         <div id="ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp-knZLVd4MevHCQ4V7kB2hf7" class="ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="babelpic-gold/images/bn:00085711v_1_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp-knZLVd4MevHCQ4V7kB2hf7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-9LJ8UBNqHHvJzjddou7PLp {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-9LJ8UBNqHHvJzjddou7PLp {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-9LJ8UBNqHHvJzjddou7PLp span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
# ...
#
#         div.ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-XzegKHe5SjZkwC5QHbeTUE">
#     <div class="ipyplot-placeholder-div-XzegKHe5SjZkwC5QHbeTUE">
#         <div id="ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE-8hk8V67zh3AVQyuB77tdPW" class="ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="babelpic-gold/images/bn:00045284n_0_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE-8hk8V67zh3AVQyuB77tdPW">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XzegKHe5SjZkwC5QHbeTUE">
#         <div id="ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE-kNx9aFgCLBQ57BA4hwPWgi" class="ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="babelpic-gold/images/bn:00045284n_1_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE-kNx9aFgCLBQ57BA4hwPWgi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XzegKHe5SjZkwC5QHbeTUE">
#         <div id="ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE-FJqiTd7Z8yHcSSZzGYxm33" class="ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="babelpic-gold/images/bn:00045284n_2_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE-FJqiTd7Z8yHcSSZzGYxm33">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XzegKHe5SjZkwC5QHbeTUE">
#         <div id="ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE-U4VmiYbGpvLjTPXBtJFUG6" class="ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="babelpic-gold/images/bn:00045284n_5_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE-U4VmiYbGpvLjTPXBtJFUG6">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-XzegKHe5SjZkwC5QHbeTUE">
#         <div id="ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE-YjQQNJNaMrspZPDzPwnask" class="ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="babelpic-gold/images/bn:00045284n_6_1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-XzegKHe5SjZkwC5QHbeTUE-YjQQNJNaMrspZPDzPwnask">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
# ----------------------------------------------------------------------------------------------------
# System
#     <style>
#         #ipyplot-html-viewer-toggle-kZ5sKhowmGfB5c6daFHUrE {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-kZ5sKhowmGfB5c6daFHUrE {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-kZ5sKhowmGfB5c6daFHUrE {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-kZ5sKhowmGfB5c6daFHUrE:checked ~ #ipyplot-html-viewer-textarea-kZ5sKhowmGfB5c6daFHUrE {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-kZ5sKhowmGfB5c6daFHUrE:checked + #ipyplot-html-viewer-label-kZ5sKhowmGfB5c6daFHUrE:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-kZ5sKhowmGfB5c6daFHUrE">
#         <label id="ipyplot-html-viewer-label-kZ5sKhowmGfB5c6daFHUrE" for="ipyplot-html-viewer-toggle-kZ5sKhowmGfB5c6daFHUrE">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-kZ5sKhowmGfB5c6daFHUrE" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-N94vzRxixkcPVeLDuMU669 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-N94vzRxixkcPVeLDuMU669]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-N94vzRxixkcPVeLDuMU669]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-N94vzRxixkcPVeLDuMU669]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-N94vzRxixkcPVeLDuMU669">
#     <div class="ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669">
#         <div id="ipyplot-content-div-N94vzRxixkcPVeLDuMU669-LkRTGUBKu3gKAwLDzARbj7" class="ipyplot-content-div-N94vzRxixkcPVeLDuMU669">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="pulled_images/bn:00045284n/0.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-N94vzRxixkcPVeLDuMU669-LkRTGUBKu3gKAwLDzARbj7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669">
#         <div id="ipyplot-content-div-N94vzRxixkcPVeLDuMU669-9XK9yHDzTvbn8pKRLSkwcv" class="ipyplot-content-div-N94vzRxixkcPVeLDuMU669">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="pulled_images/bn:00045284n/1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-N94vzRxixkcPVeLDuMU669-9XK9yHDzTvbn8pKRLSkwcv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669">
#         <div id="ipyplot-content-div-N94vzRxixkcPVeLDuMU669-HognMh6mNYjFbbWzkfFxXi" class="ipyplot-content-div-N94vzRxixkcPVeLDuMU669">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="pulled_images/bn:00045284n/2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-N94vzRxixkcPVeLDuMU669-HognMh6mNYjFbbWzkfFxXi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669">
#         <div id="ipyplot-content-div-N94vzRxixkcPVeLDuMU669-NcjCtLuET3r9XCnsyt8LzL" class="ipyplot-content-div-N94vzRxixkcPVeLDuMU669">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="pulled_images/bn:00045284n/8.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-N94vzRxixkcPVeLDuMU669-NcjCtLuET3r9XCnsyt8LzL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669">
#         <div id="ipyplot-content-div-N94vzRxixkcPVeLDuMU669-YyDoug9Gvp4SgZmVM47Kof" class="ipyplot-content-div-N94vzRxixkcPVeLDuMU669">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="pulled_images/bn:00045284n/7.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-N94vzRxixkcPVeLDuMU669-YyDoug9Gvp4SgZmVM47Kof">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-N94vzRxixkcPVeLDuMU669 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669 {
#             width: 150px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 {
#             width: 150px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 img {
#             width: 150px;
#         }
#
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-N94vzRxixkcPVeLDuMU669 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-N94vzRxixkcPVeLDuMU669]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-N94vzRxixkcPVeLDuMU669]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-N94vzRxixkcPVeLDuMU669]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-N94vzRxixkcPVeLDuMU669">
#     <div class="ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669">
#         <div id="ipyplot-content-div-N94vzRxixkcPVeLDuMU669-LkRTGUBKu3gKAwLDzARbj7" class="ipyplot-content-div-N94vzRxixkcPVeLDuMU669">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="pulled_images/bn:00045284n/0.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-N94vzRxixkcPVeLDuMU669-LkRTGUBKu3gKAwLDzARbj7">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669">
#         <div id="ipyplot-content-div-N94vzRxixkcPVeLDuMU669-9XK9yHDzTvbn8pKRLSkwcv" class="ipyplot-content-div-N94vzRxixkcPVeLDuMU669">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="pulled_images/bn:00045284n/1.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-N94vzRxixkcPVeLDuMU669-9XK9yHDzTvbn8pKRLSkwcv">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669">
#         <div id="ipyplot-content-div-N94vzRxixkcPVeLDuMU669-HognMh6mNYjFbbWzkfFxXi" class="ipyplot-content-div-N94vzRxixkcPVeLDuMU669">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <img src="pulled_images/bn:00045284n/2.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-N94vzRxixkcPVeLDuMU669-HognMh6mNYjFbbWzkfFxXi">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669">
#         <div id="ipyplot-content-div-N94vzRxixkcPVeLDuMU669-NcjCtLuET3r9XCnsyt8LzL" class="ipyplot-content-div-N94vzRxixkcPVeLDuMU669">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <img src="pulled_images/bn:00045284n/8.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-N94vzRxixkcPVeLDuMU669-NcjCtLuET3r9XCnsyt8LzL">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-N94vzRxixkcPVeLDuMU669">
#         <div id="ipyplot-content-div-N94vzRxixkcPVeLDuMU669-YyDoug9Gvp4SgZmVM47Kof" class="ipyplot-content-div-N94vzRxixkcPVeLDuMU669">
#             <h4 style="font-size: 12px; word-wrap: break-word;">5</h4>
#             <img src="pulled_images/bn:00045284n/7.jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-N94vzRxixkcPVeLDuMU669-YyDoug9Gvp4SgZmVM47Kof">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
